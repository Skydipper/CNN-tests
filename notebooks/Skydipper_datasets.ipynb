# %% [markdown]
# # Skydipper datasets for Deep Learning
#
# In this notebook we will create the Skydipper API datasets that we will use for Deep Learning.

# %%
import json
import requests
from pprint import pprint
import getpass
import time

# %% [markdown]
# **Get the token**

# %%
email = 'iker.sanchez@vizzuality.com'
password = getpass.getpass('Skydipper login password:')
# Out:
# Skydipper login password: ·········

# %%
payload = {
    "email": f"{email}",
    "password": f"{password}"
}

# %%
url = f'https://api.skydipper.com/auth/login'

headers = {'Content-Type': 'application/json'}

r = requests.post(url, data=json.dumps(payload), headers=headers)

OAUTH = r.json().get('data').get('token')

# %% [markdown]
# **Check all Skydipper datasets**

# %%
url = f'https://api.skydipper.com/v1/dataset?app=skydipper&page[size]=10000'

headers = {'Authorization': 'Bearer ' + OAUTH, 'Content-Type': 'application/json', 'Cache-Control': 'no-cache'}

r = requests.get(url, headers=headers)
pprint(r.json())
# Out:
# {'data': [{'attributes': {'application': ['skydipper'],
#                           'attributesPath': None,
#                           'blockchain': {},
#                           'clonedHost': {},
#                           'connectorType': 'rest',
#                           'connectorUrl': 'https://rw-nrt.carto.com/tables/cit_003b_air_quality_pm10/public',
#                           'createdAt': '2019-06-06T10:36:23.536Z',
#                           'dataLastUpdated': None,
#                           'dataPath': None,
#                           'env': 'production',
#                           'errorMessage': None,
#                           'geoInfo': False,
#                           'layerRelevantProps': [],
#                           'legend': {'binary': [],
#                                      'boolean': [],
#                                      'byte': [],
#                                      'country': [],
#                                      'date': [],
#                                      'double': [],
#                                      'float': [],
#                                      'half_float': [],
#                                      'integer': [],
#                                      'keyword': [],
#                                      'nested': [],
#                                      'region': [],
#                                      'scaled_float': [],
#                                      'short': [],
#                                      'text': []},
#                           'mainDateField': None,
#                           'name': 'test dataset',
#                           'overwrite': False,
#                           'protected': False,
#                           'provider': 'cartodb',
#                           'published': False,
#                           'slug': 'test-dataset',
#                           'sources': [],
#                           'status': 'pending',
#                           'subtitle': None,
#                           'tableName': 'cit_003b_air_quality_pm10',
#                           'taskId': None,
#                           'type': None,
#                           'updatedAt': '2019-06-06T10:36:23.588Z',
#                           'userId': '5cf8e9d9eb891b00118e097c',
#                           'verified': False,
#                           'widgetRelevantProps': []},
#            'id': '58cb00b6-21df-45d6-ae77-ae13479b973e',
#            'type': 'dataset'},
#           {'attributes': {'application': ['skydipper'],
#                           'attributesPath': None,
#                           'blockchain': {},
#                           'clonedHost': {},
#                           'connectorType': 'rest',
#                           'connectorUrl': 'https://rw-nrt.carto.com/tables/cit_003b_air_quality_pm10/public',
#                           'createdAt': '2019-06-06T10:49:36.901Z',
#                           'dataLastUpdated': None,
#                           'dataPath': None,
#                           'env': 'production',
#                           'errorMessage': None,
#                           'geoInfo': False,
#                           'layerRelevantProps': [],
#                           'legend': {'binary': [],
#                                      'boolean': [],
#                                      'byte': [],
#                                      'country': [],
#                                      'date': [],
#                                      'double': [],
#                                      'float': [],
#                                      'half_float': [],
#                                      'integer': [],
#                                      'keyword': [],
#                                      'nested': [],
#                                      'region': [],
#                                      'scaled_float': [],
#                                      'short': [],
#                                      'text': []},
#                           'mainDateField': None,
#                           'name': 'test dataset 002',
#                           'overwrite': False,
#                           'protected': False,
#                           'provider': 'cartodb',
#                           'published': False,
#                           'slug': 'test-dataset-002',
#                           'sources': [],
#                           'status': 'pending',
#                           'subtitle': None,
#                           'tableName': 'cit_003b_air_quality_pm10',
#                           'taskId': None,
#                           'type': None,
#                           'updatedAt': '2019-06-06T10:49:36.912Z',
#                           'userId': '5cf8e9d9eb891b00118e097c',
#                           'verified': False,
#                           'widgetRelevantProps': []},
#            'id': 'd60d377b-dd91-4052-b007-422b1f927752',
#            'type': 'dataset'},
#           {'attributes': {'application': ['skydipper'],
#                           'attributesPath': None,
#                           'blockchain': {},
#                           'clonedHost': {},
#                           'connectorType': 'rest',
#                           'connectorUrl': 'https://rw-nrt.carto.com/tables/cit_003b_air_quality_pm10/public',
#                           'createdAt': '2019-06-06T10:53:34.194Z',
#                           'dataLastUpdated': None,
#                           'dataPath': None,
#                           'env': 'production',
#                           'errorMessage': None,
#                           'geoInfo': False,
#                           'layerRelevantProps': [],
#                           'legend': {'binary': [],
#                                      'boolean': [],
#                                      'byte': [],
#                                      'country': [],
#                                      'date': [],
#                                      'double': [],
#                                      'float': [],
#                                      'half_float': [],
#                                      'integer': [],
#                                      'keyword': [],
#                                      'nested': [],
#                                      'region': [],
#                                      'scaled_float': [],
#                                      'short': [],
#                                      'text': []},
#                           'mainDateField': None,
#                           'name': 'test dataset 003',
#                           'overwrite': False,
#                           'protected': False,
#                           'provider': 'cartodb',
#                           'published': False,
#                           'slug': 'test-dataset-003',
#                           'sources': [],
#                           'status': 'pending',
#                           'subtitle': None,
#                           'tableName': 'cit_003b_air_quality_pm10',
#                           'taskId': None,
#                           'type': None,
#                           'updatedAt': '2019-06-06T10:53:34.203Z',
#                           'userId': '5cf8e9d9eb891b00118e097c',
#                           'verified': False,
#                           'widgetRelevantProps': []},
#            'id': '77e55630-9a35-40d8-bbcb-80803c87ce72',
#            'type': 'dataset'},
#           {'attributes': {'application': ['skydipper'],
#                           'attributesPath': None,
#                           'blockchain': {},
#                           'clonedHost': {},
#                           'connectorType': 'rest',
#                           'connectorUrl': 'https://wri-01.carto.com/tables/aqueduct_projections_20150309/public',
#                           'createdAt': '2019-06-06T11:00:12.658Z',
#                           'dataLastUpdated': None,
#                           'dataPath': None,
#                           'env': 'production',
#                           'errorMessage': None,
#                           'geoInfo': False,
#                           'layerRelevantProps': [],
#                           'legend': {'binary': [],
#                                      'boolean': [],
#                                      'byte': [],
#                                      'country': [],
#                                      'date': [],
#                                      'double': [],
#                                      'float': [],
#                                      'half_float': [],
#                                      'integer': [],
#                                      'keyword': [],
#                                      'nested': [],
#                                      'region': [],
#                                      'scaled_float': [],
#                                      'short': [],
#                                      'text': []},
#                           'mainDateField': None,
#                           'name': 'Seasonal variability',
#                           'overwrite': False,
#                           'protected': False,
#                           'provider': 'cartodb',
#                           'published': True,
#                           'slug': 'Seasonal-variability',
#                           'sources': [],
#                           'status': 'pending',
#                           'subtitle': None,
#                           'tableName': 'aqueduct_projections_20150309',
#                           'taskId': None,
#                           'type': None,
#                           'updatedAt': '2019-06-06T11:00:12.689Z',
#                           'userId': '5cdd1b19c20ff400117b9f25',
#                           'verified': False,
#                           'widgetRelevantProps': []},
#            'id': 'b3e28243-caec-4763-a0bc-1f0d42a8682c',
#            'type': 'dataset'},
#           {'attributes': {'application': ['skydipper'],
#                           'attributesPath': None,
#                           'blockchain': {},
#                           'clonedHost': {},
#                           'connectorType': 'rest',
#                           'connectorUrl': 'https://rw-nrt.carto.com/tables/cit_003b_air_quality_pm10/public',
#                           'createdAt': '2019-06-06T11:02:34.092Z',
#                           'dataLastUpdated': None,
#                           'dataPath': None,
#                           'env': 'production',
#                           'errorMessage': None,
#                           'geoInfo': False,
#                           'layerRelevantProps': [],
#                           'legend': {'binary': [],
#                                      'boolean': [],
#                                      'byte': [],
#                                      'country': [],
#                                      'date': [],
#                                      'double': [],
#                                      'float': [],
#                                      'half_float': [],
#                                      'integer': [],
#                                      'keyword': [],
#                                      'nested': [],
#                                      'region': [],
#                                      'scaled_float': [],
#                                      'short': [],
#                                      'text': []},
#                           'mainDateField': None,
#                           'name': 'test dataset 004',
#                           'overwrite': False,
#                           'protected': False,
#                           'provider': 'cartodb',
#                           'published': True,
#                           'slug': 'test-dataset-004',
#                           'sources': [],
#                           'status': 'pending',
#                           'subtitle': None,
#                           'tableName': 'cit_003b_air_quality_pm10',
#                           'taskId': None,
#                           'type': None,
#                           'updatedAt': '2019-06-06T11:02:34.101Z',
#                           'userId': '5cf8e9d9eb891b00118e097c',
#                           'verified': False,
#                           'widgetRelevantProps': []},
#            'id': 'a1d7cb9b-bab7-4a35-8254-fdfb4e236fc0',
#            'type': 'dataset'},
#           {'attributes': {'application': ['skydipper'],
#                           'attributesPath': None,
#                           'blockchain': {},
#                           'clonedHost': {},
#                           'connectorType': 'rest',
#                           'connectorUrl': 'https://rw-nrt.carto.com/tables/cit_003b_air_quality_pm10/public',
#                           'createdAt': '2019-06-06T11:06:06.695Z',
#                           'dataLastUpdated': None,
#                           'dataPath': None,
#                           'env': 'production',
#                           'errorMessage': None,
#                           'geoInfo': False,
#                           'layerRelevantProps': [],
#                           'legend': {'binary': [],
#                                      'boolean': [],
#                                      'byte': [],
#                                      'country': [],
#                                      'date': [],
#                                      'double': [],
#                                      'float': [],
#                                      'half_float': [],
#                                      'integer': [],
#                                      'keyword': [],
#                                      'nested': [],
#                                      'region': [],
#                                      'scaled_float': [],
#                                      'short': [],
#                                      'text': []},
#                           'mainDateField': None,
#                           'name': 'test dataset 005',
#                           'overwrite': False,
#                           'protected': False,
#                           'provider': 'cartodb',
#                           'published': True,
#                           'slug': 'test-dataset-005',
#                           'sources': [],
#                           'status': 'pending',
#                           'subtitle': None,
#                           'tableName': 'cit_003b_air_quality_pm10',
#                           'taskId': None,
#                           'type': None,
#                           'updatedAt': '2019-06-06T11:06:06.708Z',
#                           'userId': '5cf8e9d9eb891b00118e097c',
#                           'verified': False,
#                           'widgetRelevantProps': []},
#            'id': '994030e5-af29-4dfe-a6cf-e21eeab51621',
#            'type': 'dataset'},
#           {'attributes': {'application': ['skydipper'],
#                           'attributesPath': None,
#                           'blockchain': {},
#                           'clonedHost': {},
#                           'connectorType': 'rest',
#                           'connectorUrl': 'https://wri-01.carto.com/tables/aqueduct_projections_20150309/public',
#                           'createdAt': '2019-06-06T11:18:59.574Z',
#                           'dataLastUpdated': None,
#                           'dataPath': None,
#                           'env': 'production',
#                           'errorMessage': None,
#                           'geoInfo': False,
#                           'layerRelevantProps': [],
#                           'legend': {'binary': [],
#                                      'boolean': [],
#                                      'byte': [],
#                                      'country': [],
#                                      'date': [],
#                                      'double': [],
#                                      'float': [],
#                                      'half_float': [],
#                                      'integer': [],
#                                      'keyword': [],
#                                      'nested': [],
#                                      'region': [],
#                                      'scaled_float': [],
#                                      'short': [],
#                                      'text': []},
#                           'mainDateField': None,
#                           'name': 'Seasonal variability',
#                           'overwrite': False,
#                           'protected': False,
#                           'provider': 'cartodb',
#                           'published': True,
#                           'slug': 'Seasonal-variability_1',
#                           'sources': [],
#                           'status': 'pending',
#                           'subtitle': None,
#                           'tableName': 'aqueduct_projections_20150309',
#                           'taskId': None,
#                           'type': None,
#                           'updatedAt': '2019-06-06T11:18:59.630Z',
#                           'userId': '5cdd1b19c20ff400117b9f25',
#                           'verified': False,
#                           'widgetRelevantProps': []},
#            'id': 'fea74b25-5241-45db-8950-022a02ae3231',
#            'type': 'dataset'},
#           {'attributes': {'application': ['skydipper'],
#                           'attributesPath': None,
#                           'blockchain': {},
#                           'clonedHost': {},
#                           'connectorType': 'rest',
#                           'connectorUrl': 'https://wri-01.carto.com/tables/aqueduct_projections_20150309/public',
#                           'createdAt': '2019-06-06T11:23:44.073Z',
#                           'dataLastUpdated': None,
#                           'dataPath': None,
#                           'env': 'production',
#                           'errorMessage': None,
#                           'geoInfo': False,
#                           'layerRelevantProps': [],
#                           'legend': {'binary': [],
#                                      'boolean': [],
#                                      'byte': [],
#                                      'country': [],
#                                      'date': [],
#                                      'double': [],
#                                      'float': [],
#                                      'half_float': [],
#                                      'integer': [],
#                                      'keyword': [],
#                                      'nested': [],
#                                      'region': [],
#                                      'scaled_float': [],
#                                      'short': [],
#                                      'text': []},
#                           'mainDateField': None,
#                           'name': 'Seasonal variability',
#                           'overwrite': False,
#                           'protected': False,
#                           'provider': 'cartodb',
#                           'published': True,
#                           'slug': 'Seasonal-variability_2',
#                           'sources': [],
#                           'status': 'pending',
#                           'subtitle': None,
#                           'tableName': 'aqueduct_projections_20150309',
#                           'taskId': None,
#                           'type': None,
#                           'updatedAt': '2019-06-06T11:23:44.112Z',
#                           'userId': '5cdd1b19c20ff400117b9f25',
#                           'verified': False,
#                           'widgetRelevantProps': []},
#            'id': 'bf6ee0a0-cb95-43d0-851e-c9d189781ade',
#            'type': 'dataset'},
#           {'attributes': {'application': ['skydipper'],
#                           'attributesPath': None,
#                           'blockchain': {},
#                           'clonedHost': {},
#                           'connectorType': 'rest',
#                           'connectorUrl': 'https://wri-01.carto.com/tables/aqueduct_projections_20150309/public',
#                           'createdAt': '2019-06-06T11:32:33.705Z',
#                           'dataLastUpdated': None,
#                           'dataPath': None,
#                           'env': 'production',
#                           'errorMessage': '',
#                           'geoInfo': False,
#                           'layerRelevantProps': [],
#                           'legend': {'binary': [],
#                                      'boolean': [],
#                                      'byte': [],
#                                      'country': [],
#                                      'date': [],
#                                      'double': [],
#                                      'float': [],
#                                      'half_float': [],
#                                      'integer': [],
#                                      'keyword': [],
#                                      'nested': [],
#                                      'region': [],
#                                      'scaled_float': [],
#                                      'short': [],
#                                      'text': []},
#                           'mainDateField': None,
#                           'name': 'Seasonal variability',
#                           'overwrite': False,
#                           'protected': False,
#                           'provider': 'cartodb',
#                           'published': True,
#                           'slug': 'Seasonal-variability_3',
#                           'sources': [],
#                           'status': 'saved',
#                           'subtitle': None,
#                           'tableName': 'aqueduct_projections_20150309',
#                           'taskId': None,
#                           'type': None,
#                           'updatedAt': '2019-06-06T11:32:34.517Z',
#                           'userId': '5cdd1b19c20ff400117b9f25',
#                           'verified': False,
#                           'widgetRelevantProps': []},
#            'id': '70d0cc83-a119-40dd-81f3-177c7a32bfee',
#            'type': 'dataset'},
#           {'attributes': {'application': ['skydipper'],
#                           'attributesPath': None,
#                           'blockchain': {},
#                           'clonedHost': {},
#                           'connectorType': 'rest',
#                           'connectorUrl': None,
#                           'createdAt': '2019-06-11T16:18:09.845Z',
#                           'dataLastUpdated': None,
#                           'dataPath': None,
#                           'env': 'production',
#                           'errorMessage': None,
#                           'geoInfo': False,
#                           'layerRelevantProps': [],
#                           'legend': {'binary': [],
#                                      'boolean': [],
#                                      'byte': [],
#                                      'country': [],
#                                      'date': [],
#                                      'double': [],
#                                      'float': [],
#                                      'half_float': [],
#                                      'integer': [],
#                                      'keyword': [],
#                                      'nested': [],
#                                      'region': [],
#                                      'scaled_float': [],
#                                      'short': [],
#                                      'text': []},
#                           'mainDateField': None,
#                           'name': 'test GEE ECM 001',
#                           'overwrite': False,
#                           'protected': False,
#                           'provider': 'gee',
#                           'published': True,
#                           'slug': 'test-GEE-ECM-001',
#                           'sources': [],
#                           'status': 'pending',
#                           'subtitle': None,
#                           'tableName': 'UMD/hansen/global_forest_change_2013',
#                           'taskId': None,
#                           'type': None,
#                           'updatedAt': '2019-06-11T16:18:09.884Z',
#                           'userId': '5cf8e9d9eb891b00118e097c',
#                           'verified': False,
#                           'widgetRelevantProps': []},
#            'id': 'c55958c6-1246-4833-96ee-6b9135c8d6d7',
#            'type': 'dataset'},
#           {'attributes': {'application': ['skydipper'],
#                           'attributesPath': None,
#                           'blockchain': {},
#                           'clonedHost': {},
#                           'connectorType': 'rest',
#                           'connectorUrl': None,
#                           'createdAt': '2019-06-11T16:42:47.902Z',
#                           'dataLastUpdated': None,
#                           'dataPath': None,
#                           'env': 'production',
#                           'errorMessage': None,
#                           'geoInfo': False,
#                           'layerRelevantProps': [],
#                           'legend': {'binary': [],
#                                      'boolean': [],
#                                      'byte': [],
#                                      'country': [],
#                                      'date': [],
#                                      'double': [],
#                                      'float': [],
#                                      'half_float': [],
#                                      'integer': [],
#                                      'keyword': [],
#                                      'nested': [],
#                                      'region': [],
#                                      'scaled_float': [],
#                                      'short': [],
#                                      'text': []},
#                           'mainDateField': None,
#                           'name': 'test GEE ECM 001',
#                           'overwrite': False,
#                           'protected': False,
#                           'provider': 'gee',
#                           'published': True,
#                           'slug': 'test-GEE-ECM-001_1',
#                           'sources': [],
#                           'status': 'pending',
#                           'subtitle': None,
#                           'tableName': 'UMD/hansen/global_forest_change_2013',
#                           'taskId': None,
#                           'type': None,
#                           'updatedAt': '2019-06-11T16:42:47.937Z',
#                           'userId': '5cf8e9d9eb891b00118e097c',
#                           'verified': False,
#                           'widgetRelevantProps': []},
#            'id': '6371307a-1512-4eb3-9355-0791453f1efb',
#            'type': 'dataset'},
#           {'attributes': {'application': ['skydipper'],
#                           'attributesPath': None,
#                           'blockchain': {},
#                           'clonedHost': {},
#                           'connectorType': 'rest',
#                           'connectorUrl': 'https://wri-rw.carto.com/tables/hydrobasins_fao_fiona_merged_v01/public',
#                           'createdAt': '2019-11-11T12:37:10.446Z',
#                           'dataLastUpdated': None,
#                           'dataPath': None,
#                           'env': 'production',
#                           'errorMessage': '',
#                           'geoInfo': False,
#                           'layerRelevantProps': [],
#                           'legend': {'binary': [],
#                                      'boolean': [],
#                                      'byte': [],
#                                      'country': [],
#                                      'date': [],
#                                      'double': [],
#                                      'float': [],
#                                      'half_float': [],
#                                      'integer': [],
#                                      'keyword': [],
#                                      'nested': [],
#                                      'region': [],
#                                      'scaled_float': [],
#                                      'short': [],
#                                      'text': []},
#                           'mainDateField': None,
#                           'name': 'FAO hydrobasins',
#                           'overwrite': False,
#                           'protected': False,
#                           'provider': 'cartodb',
#                           'published': False,
#                           'slug': 'FAO-hydrobasins',
#                           'sources': [],
#                           'status': 'saved',
#                           'subtitle': None,
#                           'tableName': 'hydrobasins_fao_fiona_merged_v01',
#                           'taskId': None,
#                           'type': None,
#                           'updatedAt': '2019-11-11T12:37:11.239Z',
#                           'userId': '5dc9210cbe566d0010df6752',
#                           'verified': False,
#                           'widgetRelevantProps': []},
#            'id': '640adc03-5fc4-46ff-bfcf-e622d430fed4',
#            'type': 'dataset'},
#           {'attributes': {'application': ['skydipper'],
#                           'attributesPath': None,
#                           'blockchain': {},
#                           'clonedHost': {},
#                           'connectorType': 'rest',
#                           'connectorUrl': None,
#                           'createdAt': '2019-11-15T10:25:30.592Z',
#                           'dataLastUpdated': None,
#                           'dataPath': None,
#                           'env': 'production',
#                           'errorMessage': None,
#                           'geoInfo': False,
#                           'layerRelevantProps': [],
#                           'legend': {'binary': [],
#                                      'boolean': [],
#                                      'byte': [],
#                                      'country': [],
#                                      'date': [],
#                                      'double': [],
#                                      'float': [],
#                                      'half_float': [],
#                                      'integer': [],
#                                      'keyword': [],
#                                      'nested': [],
#                                      'region': [],
#                                      'scaled_float': [],
#                                      'short': [],
#                                      'text': []},
#                           'mainDateField': None,
#                           'name': 'bio.014 Biodiversity Intactness',
#                           'overwrite': False,
#                           'protected': False,
#                           'provider': 'gee',
#                           'published': False,
#                           'slug': 'bio014-Biodiversity-Intactness',
#                           'sources': [],
#                           'status': 'pending',
#                           'subtitle': None,
#                           'tableName': 'users/resourcewatch/bio_014_bio_intactness',
#                           'taskId': None,
#                           'type': 'raster',
#                           'updatedAt': '2019-11-15T10:25:30.650Z',
#                           'userId': '5dc9210cbe566d0010df6752',
#                           'verified': False,
#                           'widgetRelevantProps': []},
#            'id': '94241cb4-9e91-4a1a-9fcc-993b8ac9c2b7',
#            'type': 'dataset'},
#           {'attributes': {'application': ['skydipper'],
#                           'attributesPath': None,
#                           'blockchain': {},
#                           'clonedHost': {},
#                           'connectorType': 'rest',
#                           'connectorUrl': None,
#                           'createdAt': '2019-12-19T12:11:24.197Z',
#                           'dataLastUpdated': None,
#                           'dataPath': None,
#                           'env': 'production',
#                           'errorMessage': None,
#                           'geoInfo': False,
#                           'layerRelevantProps': [],
#                           'legend': {'binary': [],
#                                      'boolean': [],
#                                      'byte': [],
#                                      'country': [],
#                                      'date': [],
#                                      'double': [],
#                                      'float': [],
#                                      'half_float': [],
#                                      'integer': [],
#                                      'keyword': [],
#                                      'nested': [],
#                                      'region': [],
#                                      'scaled_float': [],
#                                      'short': [],
#                                      'text': []},
#                           'mainDateField': None,
#                           'name': 'Sentinel 2 Top-of-Atmosphere Reflectance',
#                           'overwrite': False,
#                           'protected': False,
#                           'provider': 'gee',
#                           'published': False,
#                           'slug': 'Sentinel-2-Top-of-Atmosphere-Reflectance',
#                           'sources': [],
#                           'status': 'pending',
#                           'subtitle': None,
#                           'tableName': 'COPERNICUS/S2',
#                           'taskId': None,
#                           'type': 'raster',
#                           'updatedAt': '2019-12-19T12:11:24.249Z',
#                           'userId': '5dc9210cbe566d0010df6752',
#                           'verified': False,
#                           'widgetRelevantProps': []},
#            'id': 'ad17a162-2d60-4b23-a344-6455b64e56cb',
#            'type': 'dataset'},
#           {'attributes': {'application': ['skydipper'],
#                           'attributesPath': None,
#                           'blockchain': {},
#                           'clonedHost': {},
#                           'connectorType': 'rest',
#                           'connectorUrl': None,
#                           'createdAt': '2019-12-19T12:11:29.520Z',
#                           'dataLastUpdated': None,
#                           'dataPath': None,
#                           'env': 'production',
#                           'errorMessage': None,
#                           'geoInfo': False,
#                           'layerRelevantProps': [],
#                           'legend': {'binary': [],
#                                      'boolean': [],
#                                      'byte': [],
#                                      'country': [],
#                                      'date': [],
#                                      'double': [],
#                                      'float': [],
#                                      'half_float': [],
#                                      'integer': [],
#                                      'keyword': [],
#                                      'nested': [],
#                                      'region': [],
#                                      'scaled_float': [],
#                                      'short': [],
#                                      'text': []},
#                           'mainDateField': None,
#                           'name': 'Landsat 7 Surface Reflectance',
#                           'overwrite': False,
#                           'protected': False,
#                           'provider': 'gee',
#                           'published': False,
#                           'slug': 'Landsat-7-Surface-Reflectance',
#                           'sources': [],
#                           'status': 'pending',
#                           'subtitle': None,
#                           'tableName': 'LANDSAT/LE07/C01/T1_SR',
#                           'taskId': None,
#                           'type': 'raster',
#                           'updatedAt': '2019-12-19T12:11:29.553Z',
#                           'userId': '5dc9210cbe566d0010df6752',
#                           'verified': False,
#                           'widgetRelevantProps': []},
#            'id': 'd69ac786-4fe0-4f7b-831e-49c869dd85a5',
#            'type': 'dataset'},
#           {'attributes': {'application': ['skydipper'],
#                           'attributesPath': None,
#                           'blockchain': {},
#                           'clonedHost': {},
#                           'connectorType': 'rest',
#                           'connectorUrl': None,
#                           'createdAt': '2019-12-19T12:11:34.698Z',
#                           'dataLastUpdated': None,
#                           'dataPath': None,
#                           'env': 'production',
#                           'errorMessage': None,
#                           'geoInfo': False,
#                           'layerRelevantProps': [],
#                           'legend': {'binary': [],
#                                      'boolean': [],
#                                      'byte': [],
#                                      'country': [],
#                                      'date': [],
#                                      'double': [],
#                                      'float': [],
#                                      'half_float': [],
#                                      'integer': [],
#                                      'keyword': [],
#                                      'nested': [],
#                                      'region': [],
#                                      'scaled_float': [],
#                                      'short': [],
#                                      'text': []},
#                           'mainDateField': None,
#                           'name': 'Landsat 8 Surface Reflectance',
#                           'overwrite': False,
#                           'protected': False,
#                           'provider': 'gee',
#                           'published': False,
#                           'slug': 'Landsat-8-Surface-Reflectance',
#                           'sources': [],
#                           'status': 'pending',
#                           'subtitle': None,
#                           'tableName': 'LANDSAT/LC08/C01/T1_SR',
#                           'taskId': None,
#                           'type': 'raster',
#                           'updatedAt': '2019-12-19T12:11:34.747Z',
#                           'userId': '5dc9210cbe566d0010df6752',
#                           'verified': False,
#                           'widgetRelevantProps': []},
#            'id': 'e0631b7f-f00a-4686-9fa5-a337a96327b7',
#            'type': 'dataset'},
#           {'attributes': {'application': ['skydipper'],
#                           'attributesPath': None,
#                           'blockchain': {},
#                           'clonedHost': {},
#                           'connectorType': 'rest',
#                           'connectorUrl': None,
#                           'createdAt': '2019-12-19T12:11:39.881Z',
#                           'dataLastUpdated': None,
#                           'dataPath': None,
#                           'env': 'production',
#                           'errorMessage': None,
#                           'geoInfo': False,
#                           'layerRelevantProps': [],
#                           'legend': {'binary': [],
#                                      'boolean': [],
#                                      'byte': [],
#                                      'country': [],
#                                      'date': [],
#                                      'double': [],
#                                      'float': [],
#                                      'half_float': [],
#                                      'integer': [],
#                                      'keyword': [],
#                                      'nested': [],
#                                      'region': [],
#                                      'scaled_float': [],
#                                      'short': [],
#                                      'text': []},
#                           'mainDateField': None,
#                           'name': 'USDA NASS Cropland Data Layers',
#                           'overwrite': False,
#                           'protected': False,
#                           'provider': 'gee',
#                           'published': False,
#                           'slug': 'USDA-NASS-Cropland-Data-Layers',
#                           'sources': [],
#                           'status': 'pending',
#                           'subtitle': None,
#                           'tableName': 'USDA/NASS/CDL',
#                           'taskId': None,
#                           'type': 'raster',
#                           'updatedAt': '2019-12-19T12:11:39.923Z',
#                           'userId': '5dc9210cbe566d0010df6752',
#                           'verified': False,
#                           'widgetRelevantProps': []},
#            'id': '58f51db5-942d-4b62-9889-d24a83e7be65',
#            'type': 'dataset'},
#           {'attributes': {'application': ['skydipper'],
#                           'attributesPath': None,
#                           'blockchain': {},
#                           'clonedHost': {},
#                           'connectorType': 'rest',
#                           'connectorUrl': None,
#                           'createdAt': '2019-12-19T12:11:45.053Z',
#                           'dataLastUpdated': None,
#                           'dataPath': None,
#                           'env': 'production',
#                           'errorMessage': None,
#                           'geoInfo': False,
#                           'layerRelevantProps': [],
#                           'legend': {'binary': [],
#                                      'boolean': [],
#                                      'byte': [],
#                                      'country': [],
#                                      'date': [],
#                                      'double': [],
#                                      'float': [],
#                                      'half_float': [],
#                                      'integer': [],
#                                      'keyword': [],
#                                      'nested': [],
#                                      'region': [],
#                                      'scaled_float': [],
#                                      'short': [],
#                                      'text': []},
#                           'mainDateField': None,
#                           'name': 'USGS National Land Cover Database',
#                           'overwrite': False,
#                           'protected': False,
#                           'provider': 'gee',
#                           'published': False,
#                           'slug': 'USGS-National-Land-Cover-Database',
#                           'sources': [],
#                           'status': 'pending',
#                           'subtitle': None,
#                           'tableName': 'USGS/NLCD',
#                           'taskId': None,
#                           'type': 'raster',
#                           'updatedAt': '2019-12-19T12:11:45.087Z',
#                           'userId': '5dc9210cbe566d0010df6752',
#                           'verified': False,
#                           'widgetRelevantProps': []},
#            'id': '072a64f3-bee3-4ac3-80de-4dd509ea45fc',
#            'type': 'dataset'},
#           {'attributes': {'application': ['skydipper'],
#                           'attributesPath': None,
#                           'blockchain': {},
#                           'clonedHost': {},
#                           'connectorType': 'document',
#                           'connectorUrl': 'http://skydipper-api.s3.amazonaws.com/raw/1576840733910_sample.csv',
#                           'createdAt': '2019-12-20T11:41:07.255Z',
#                           'dataLastUpdated': None,
#                           'dataPath': None,
#                           'env': 'production',
#                           'errorMessage': None,
#                           'geoInfo': False,
#                           'layerRelevantProps': [],
#                           'legend': {'binary': [],
#                                      'boolean': [],
#                                      'byte': [],
#                                      'country': [],
#                                      'date': [],
#                                      'double': [],
#                                      'float': [],
#                                      'half_float': [],
#                                      'integer': [],
#                                      'keyword': [],
#                                      'nested': [],
#                                      'region': [],
#                                      'scaled_float': [],
#                                      'short': [],
#                                      'text': []},
#                           'mainDateField': None,
#                           'name': 'csv_test',
#                           'overwrite': False,
#                           'protected': False,
#                           'provider': 'csv',
#                           'published': True,
#                           'slug': 'csv_test',
#                           'sources': [],
#                           'status': 'pending',
#                           'subtitle': None,
#                           'tableName': None,
#                           'taskId': None,
#                           'type': None,
#                           'updatedAt': '2019-12-20T11:41:07.285Z',
#                           'userId': '5dc920f2be566d0010df674d',
#                           'verified': False,
#                           'widgetRelevantProps': []},
#            'id': '35f90ea3-91d3-42a8-bd29-060a0cd48611',
#            'type': 'dataset'},
#           {'attributes': {'application': ['skydipper'],
#                           'attributesPath': None,
#                           'blockchain': {},
#                           'clonedHost': {},
#                           'connectorType': 'document',
#                           'connectorUrl': 'http://skydipper-api.s3.amazonaws.com/raw/1576843046279_sample_df.csv',
#                           'createdAt': '2019-12-20T11:57:50.733Z',
#                           'dataLastUpdated': None,
#                           'dataPath': None,
#                           'env': 'production',
#                           'errorMessage': None,
#                           'geoInfo': False,
#                           'layerRelevantProps': [],
#                           'legend': {'binary': [],
#                                      'boolean': [],
#                                      'byte': [],
#                                      'country': [],
#                                      'date': [],
#                                      'double': [],
#                                      'float': [],
#                                      'half_float': [],
#                                      'integer': [],
#                                      'keyword': [],
#                                      'nested': [],
#                                      'region': [],
#                                      'scaled_float': [],
#                                      'short': [],
#                                      'text': []},
#                           'mainDateField': None,
#                           'name': 'csv_test',
#                           'overwrite': False,
#                           'protected': False,
#                           'provider': 'csv',
#                           'published': True,
#                           'slug': 'csv_test_1',
#                           'sources': [],
#                           'status': 'pending',
#                           'subtitle': None,
#                           'tableName': None,
#                           'taskId': None,
#                           'type': None,
#                           'updatedAt': '2019-12-20T11:57:50.757Z',
#                           'userId': '5dc920f2be566d0010df674d',
# ...
#                           'mainDateField': None,
#                           'name': 'Carto_testXX',
#                           'overwrite': False,
#                           'protected': False,
#                           'provider': 'cartodb',
#                           'published': True,
#                           'slug': 'Carto_testXX_1',
#                           'sources': [],
#                           'status': 'saved',
#                           'subtitle': None,
#                           'tableName': 'gadm36_countries',
#                           'taskId': None,
#                           'type': None,
#                           'updatedAt': '2020-01-15T16:13:42.530Z',
#                           'userId': '5dc920f2be566d0010df674d',
#                           'verified': False,
#                           'widgetRelevantProps': []},
#            'id': 'd3a1184e-2a6f-48f5-b920-16fff69e7132',
#            'type': 'dataset'},
#           {'attributes': {'application': ['skydipper'],
#                           'attributesPath': None,
#                           'blockchain': {},
#                           'clonedHost': {},
#                           'connectorType': 'rest',
#                           'connectorUrl': 'http://35.233.41.65/user/sky '
#                                           'dipper/dataset/adm2_biovartest',
#                           'createdAt': '2020-01-15T16:22:10.020Z',
#                           'dataLastUpdated': None,
#                           'dataPath': None,
#                           'env': 'production',
#                           'errorMessage': '',
#                           'geoInfo': False,
#                           'layerRelevantProps': [],
#                           'legend': {'binary': [],
#                                      'boolean': [],
#                                      'byte': [],
#                                      'country': [],
#                                      'date': [],
#                                      'double': [],
#                                      'float': [],
#                                      'half_float': [],
#                                      'integer': [],
#                                      'keyword': [],
#                                      'nested': [],
#                                      'region': [],
#                                      'scaled_float': [],
#                                      'short': [],
#                                      'text': []},
#                           'mainDateField': None,
#                           'name': 'Spain_adm_test',
#                           'overwrite': False,
#                           'protected': False,
#                           'provider': 'cartodb',
#                           'published': True,
#                           'slug': 'Spain_adm_test',
#                           'sources': [],
#                           'status': 'saved',
#                           'subtitle': None,
#                           'tableName': 'adm2_biovartest',
#                           'taskId': None,
#                           'type': None,
#                           'updatedAt': '2020-01-15T16:22:10.162Z',
#                           'userId': '5dc920f2be566d0010df674d',
#                           'verified': False,
#                           'widgetRelevantProps': []},
#            'id': '465e42e5-0336-408c-99b0-175aa5ff4bab',
#            'type': 'dataset'},
#           {'attributes': {'application': ['skydipper'],
#                           'attributesPath': None,
#                           'blockchain': {},
#                           'clonedHost': {},
#                           'connectorType': 'rest',
#                           'connectorUrl': 'http://35.233.41.65/user/skydipper/dataset/adm2_biovartest',
#                           'createdAt': '2020-01-15T16:23:31.777Z',
#                           'dataLastUpdated': None,
#                           'dataPath': None,
#                           'env': 'production',
#                           'errorMessage': '',
#                           'geoInfo': False,
#                           'layerRelevantProps': [],
#                           'legend': {'binary': [],
#                                      'boolean': [],
#                                      'byte': [],
#                                      'country': [],
#                                      'date': [],
#                                      'double': [],
#                                      'float': [],
#                                      'half_float': [],
#                                      'integer': [],
#                                      'keyword': [],
#                                      'nested': [],
#                                      'region': [],
#                                      'scaled_float': [],
#                                      'short': [],
#                                      'text': []},
#                           'mainDateField': None,
#                           'name': 'Spain Admin level 2',
#                           'overwrite': False,
#                           'protected': False,
#                           'provider': 'cartodb',
#                           'published': True,
#                           'slug': 'Spain_adm_test_1',
#                           'sources': [],
#                           'status': 'saved',
#                           'subtitle': None,
#                           'tableName': 'adm2_biovartest',
#                           'taskId': None,
#                           'type': None,
#                           'updatedAt': '2020-01-15T16:28:10.671Z',
#                           'userId': '5dc920f2be566d0010df674d',
#                           'verified': False,
#                           'widgetRelevantProps': []},
#            'id': '5dd09e0b-cffa-4e42-8c5a-21d6d71bad50',
#            'type': 'dataset'},
#           {'attributes': {'application': ['skydipper'],
#                           'attributesPath': None,
#                           'blockchain': {},
#                           'clonedHost': {},
#                           'connectorType': 'rest',
#                           'connectorUrl': 'http://35.233.41.65/user/skydipper/dataset/adm2_biovartest',
#                           'createdAt': '2020-01-23T16:55:30.893Z',
#                           'dataLastUpdated': None,
#                           'dataPath': None,
#                           'env': 'production',
#                           'errorMessage': '',
#                           'geoInfo': False,
#                           'layerRelevantProps': [],
#                           'legend': {'binary': [],
#                                      'boolean': [],
#                                      'byte': [],
#                                      'country': [],
#                                      'date': [],
#                                      'double': [],
#                                      'float': [],
#                                      'half_float': [],
#                                      'integer': [],
#                                      'keyword': [],
#                                      'nested': [],
#                                      'region': [],
#                                      'scaled_float': [],
#                                      'short': [],
#                                      'text': []},
#                           'mainDateField': None,
#                           'name': 'Spain_adm_test',
#                           'overwrite': False,
#                           'protected': False,
#                           'provider': 'cartodb',
#                           'published': True,
#                           'slug': 'Spain_adm_test_2',
#                           'sources': [],
#                           'status': 'saved',
#                           'subtitle': None,
#                           'tableName': 'adm2_biovartest',
#                           'taskId': None,
#                           'type': None,
#                           'updatedAt': '2020-01-23T16:55:31.054Z',
#                           'userId': '5dc920f2be566d0010df674d',
#                           'verified': False,
#                           'widgetRelevantProps': []},
#            'id': '6a3ff02f-7b33-4ce5-85c2-3b2ea5bac7a0',
#            'type': 'dataset'},
#           {'attributes': {'application': ['skydipper'],
#                           'attributesPath': None,
#                           'blockchain': {},
#                           'clonedHost': {},
#                           'connectorType': 'rest',
#                           'connectorUrl': 'http://35.233.41.65/user/skydipper/dataset/adm2_biovartest',
#                           'createdAt': '2020-01-27T10:00:13.796Z',
#                           'dataLastUpdated': None,
#                           'dataPath': None,
#                           'env': 'production',
#                           'errorMessage': '',
#                           'geoInfo': False,
#                           'layerRelevantProps': [],
#                           'legend': {'binary': [],
#                                      'boolean': [],
#                                      'byte': [],
#                                      'country': [],
#                                      'date': [],
#                                      'double': [],
#                                      'float': [],
#                                      'half_float': [],
#                                      'integer': [],
#                                      'keyword': [],
#                                      'nested': [],
#                                      'region': [],
#                                      'scaled_float': [],
#                                      'short': [],
#                                      'text': []},
#                           'mainDateField': None,
#                           'name': 'Spain_adm_test',
#                           'overwrite': False,
#                           'protected': False,
#                           'provider': 'cartodb',
#                           'published': False,
#                           'slug': 'Spain_adm_test_3',
#                           'sources': [],
#                           'status': 'saved',
#                           'subtitle': None,
#                           'tableName': 'adm2_biovartest',
#                           'taskId': None,
#                           'type': None,
#                           'updatedAt': '2020-01-27T10:00:13.927Z',
#                           'userId': '5e21aafba685f300108df32c',
#                           'verified': False,
#                           'widgetRelevantProps': []},
#            'id': 'fa7a3e5a-3c21-4e24-b2d0-cc0a1d38cb41',
#            'type': 'dataset'},
#           {'attributes': {'application': ['skydipper'],
#                           'attributesPath': None,
#                           'blockchain': {},
#                           'clonedHost': {},
#                           'connectorType': 'rest',
#                           'connectorUrl': 'http://35.233.41.65/user/skydipper/dataset/adm2_biovartest',
#                           'createdAt': '2020-01-27T13:45:10.154Z',
#                           'dataLastUpdated': None,
#                           'dataPath': None,
#                           'env': 'production',
#                           'errorMessage': '',
#                           'geoInfo': False,
#                           'layerRelevantProps': [],
#                           'legend': {'binary': [],
#                                      'boolean': [],
#                                      'byte': [],
#                                      'country': [],
#                                      'date': [],
#                                      'double': [],
#                                      'float': [],
#                                      'half_float': [],
#                                      'integer': [],
#                                      'keyword': [],
#                                      'nested': [],
#                                      'region': [],
#                                      'scaled_float': [],
#                                      'short': [],
#                                      'text': []},
#                           'mainDateField': None,
#                           'name': 'Spain_adm_test',
#                           'overwrite': False,
#                           'protected': False,
#                           'provider': 'cartodb',
#                           'published': False,
#                           'slug': 'Spain_adm_test_4',
#                           'sources': [],
#                           'status': 'saved',
#                           'subtitle': None,
#                           'tableName': 'adm2_biovartest',
#                           'taskId': None,
#                           'type': None,
#                           'updatedAt': '2020-01-27T13:45:10.266Z',
#                           'userId': '5e21aafba685f300108df32c',
#                           'verified': False,
#                           'widgetRelevantProps': []},
#            'id': 'c11dc884-3f89-4970-9e03-62976c86159f',
#            'type': 'dataset'},
#           {'attributes': {'application': ['skydipper'],
#                           'attributesPath': None,
#                           'blockchain': {},
#                           'clonedHost': {},
#                           'connectorType': 'rest',
#                           'connectorUrl': 'http://35.233.41.65/user/skydipper/dataset/adm2_biovartest',
#                           'createdAt': '2020-01-27T14:40:42.787Z',
#                           'dataLastUpdated': None,
#                           'dataPath': None,
#                           'env': 'production',
#                           'errorMessage': '',
#                           'geoInfo': False,
#                           'layerRelevantProps': [],
#                           'legend': {'binary': [],
#                                      'boolean': [],
#                                      'byte': [],
#                                      'country': [],
#                                      'date': [],
#                                      'double': [],
#                                      'float': [],
#                                      'half_float': [],
#                                      'integer': [],
#                                      'keyword': [],
#                                      'nested': [],
#                                      'region': [],
#                                      'scaled_float': [],
#                                      'short': [],
#                                      'text': []},
#                           'mainDateField': None,
#                           'name': 'Spain_adm_test',
#                           'overwrite': False,
#                           'protected': False,
#                           'provider': 'cartodb',
#                           'published': False,
#                           'slug': 'Spain_adm_test_5',
#                           'sources': [],
#                           'status': 'saved',
#                           'subtitle': None,
#                           'tableName': 'adm2_biovartest',
#                           'taskId': None,
#                           'type': None,
#                           'updatedAt': '2020-01-27T14:40:42.916Z',
#                           'userId': '5e21aafba685f300108df32c',
#                           'verified': False,
#                           'widgetRelevantProps': []},
#            'id': '7804317b-8a0c-4f56-a746-148601b83699',
#            'type': 'dataset'}],
#  'links': {'first': 'http://api.skydipper.com/v1/dataset?app=skydipper&page[number]=1&page[size]=10000',
#            'last': 'http://api.skydipper.com/v1/dataset?app=skydipper&page[number]=1&page[size]=10000',
#            'next': 'http://api.skydipper.com/v1/dataset?app=skydipper&page[number]=1&page[size]=10000',
#            'prev': 'http://api.skydipper.com/v1/dataset?app=skydipper&page[number]=1&page[size]=10000',
#            'self': 'http://api.skydipper.com/v1/dataset?app=skydipper&page[number]=1&page[size]=10000'},
#  'meta': {'size': 10000, 'total-items': 61, 'total-pages': 1}}

# %% [markdown]
# ## Create datasets for Deep Learning
# ### Register GEE datasets
# - **[Sentinel 2 Top-of-Atmosphere Reflectance](https://developers.google.com/earth-engine/datasets/catalog/COPERNICUS_S2)**
# - **[Landsat 7 Surface Reflectance](https://developers.google.com/earth-engine/datasets/catalog/LANDSAT_LE07_C01_T1_SR)**
# - **[Landsat 8 Surface Reflectance](https://developers.google.com/earth-engine/datasets/catalog/LANDSAT_LC08_C01_T1_SR)**
# - **[USDA NASS Cropland Data Layers](https://developers.google.com/earth-engine/datasets/catalog/USDA_NASS_CDL)**
# - **[USGS National Land Cover Database](https://developers.google.com/earth-engine/datasets/catalog/USGS_NLCD)**
# - **[Lake Water Quality 100m](https://land.copernicus.eu/global/products/lwq)**

# %%
datasets = {"Sentinel 2 Top-of-Atmosphere Reflectance": "COPERNICUS/S2",
            "Landsat 7 Surface Reflectance": "LANDSAT/LE07/C01/T1_SR",
            "Landsat 8 Surface Reflectance": "LANDSAT/LC08/C01/T1_SR",
            "USDA NASS Cropland Data Layers": "USDA/NASS/CDL",
            "USGS National Land Cover Database": "USGS/NLCD",
            "Lake Water Quality 100m": "projects/vizzuality/skydipper-water-quality/LWQ-100m"
           }

# %%
datasets = {
            "Lake Water Quality 100m": "projects/vizzuality/skydipper-water-quality/LWQ-100m"
           }

# %%
def post_ee_datasets(datasets, OAUTH):
    for dataset_name in datasets.keys():
        payload = {"dataset": {
                    "name": dataset_name,
                    "application": ["skydipper"],
                    "type": "raster",
                    "connectorType": "rest",
                    "provider": "gee",
                    "tableName": datasets[dataset_name],
                    "status": "saved",
                    "published": True,
                    "overwrite": False,
                    "verified": False,
                    "env": "production",
                }
        }
        
        #Post new dataset
        url = f'https://api.skydipper.com/v1/dataset'
        
        headers = {'Authorization': 'Bearer ' + OAUTH, 'Content-Type': 'application/json', 'Cache-Control': 'no-cache'}
        
        r = requests.post(url, data=json.dumps(payload), headers=headers)
        
        pprint(r.json())
        time.sleep(5)

# %%
post_ee_datasets(datasets, OAUTH)
# Out:
# {'data': {'attributes': {'application': ['skydipper'],
#                          'attributesPath': None,
#                          'blockchain': {},
#                          'clonedHost': {},
#                          'connectorType': 'rest',
#                          'connectorUrl': None,
#                          'createdAt': '2020-01-31T09:32:59.902Z',
#                          'dataLastUpdated': None,
#                          'dataPath': None,
#                          'env': 'production',
#                          'errorMessage': None,
#                          'geoInfo': False,
#                          'layerRelevantProps': [],
#                          'legend': {'binary': [],
#                                     'boolean': [],
#                                     'byte': [],
#                                     'country': [],
#                                     'date': [],
#                                     'double': [],
#                                     'float': [],
#                                     'half_float': [],
#                                     'integer': [],
#                                     'keyword': [],
#                                     'nested': [],
#                                     'region': [],
#                                     'scaled_float': [],
#                                     'short': [],
#                                     'text': []},
#                          'mainDateField': None,
#                          'name': 'Lake Water Quality 100m',
#                          'overwrite': False,
#                          'protected': False,
#                          'provider': 'gee',
#                          'published': True,
#                          'slug': 'Lake-Water-Quality-100m',
#                          'sources': [],
#                          'status': 'pending',
#                          'subtitle': None,
#                          'tableName': 'projects/vizzuality/skydipper-water-quality/LWQ-100m',
#                          'taskId': None,
#                          'type': 'raster',
#                          'updatedAt': '2020-01-31T09:32:59.935Z',
#                          'userId': '5dc9210cbe566d0010df6752',
#                          'verified': False,
#                          'widgetRelevantProps': []},
#           'id': 'c75ea9c7-4860-4b9c-8ecd-1b4c8902fdb4',
#           'type': 'dataset'}}

# %%
import Skydipper

# %%
slugs_list = ["Sentinel-2-Top-of-Atmosphere-Reflectance",
              "Landsat-7-Surface-Reflectance",
              "Landsat-8-Surface-Reflectance",
              "USDA-NASS-Cropland-Data-Layers",
              "USGS-National-Land-Cover-Database",
              "Lake-Water-Quality-100m"]

# %%
c = Skydipper.Collection(search=' '.join(slugs_list), object_type=['dataset'], app=['skydipper'], limit=10)
c
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-12-52d0305b83c8> in <module>
# ----> 1 c = Skydipper.Collection(search=' '.join(slugs_list), object_type=['dataset'], app=['skydipper'], limit=10)
#       2 c
#
# ~/anaconda3/envs/py36tf115/lib/python3.6/site-packages/Skydipper/collection.py in __init__(self, search, app, env, limit, order, sort, object_type, server, filters, mapbox_token)
#      48         self.mapbox_token = mapbox_token
#      49         self.object_type = object_type
# ---> 50         self.collection = self.get_collection()
#      51         self.iter_position = 0
#      52
#
# ~/anaconda3/envs/py36tf115/lib/python3.6/site-packages/Skydipper/collection.py in get_collection(self)
#      94         are the objects in the API. I.e. tables are a dataset type.
#      95         """
# ---> 96         datasets = self.get_entities()
#      97         layers = []
#      98         for d in datasets:
#
# ~/anaconda3/envs/py36tf115/lib/python3.6/site-packages/Skydipper/collection.py in get_entities(self)
#     126                    f'includes=layer,metadata&page[size]=1000&hash={hash}')
#     127         r = requests.get(url)
# --> 128         response_list = r.json().get('data', None)
#     129         if not response_list:
#     130             raise ValueError('No items found')
#
# ~/anaconda3/envs/py36tf115/lib/python3.6/site-packages/requests/models.py in json(self, **kwargs)
#     887                 try:
#     888                     return complexjson.loads(
# --> 889                         self.content.decode(encoding), **kwargs
#     890                     )
#     891                 except UnicodeDecodeError:
#
# ~/anaconda3/envs/py36tf115/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# ~/anaconda3/envs/py36tf115/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# ~/anaconda3/envs/py36tf115/lib/python3.6/json/decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
